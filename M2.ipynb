# %% [markdown]
# ## DATA VISUALIZATION AND DATA ANALYSIS

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# C:\Users\abhi\AppData\Local\Temp\ipykernel_27092\781345070.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df=pd.read_csv('Data.csv')


df.head()
# Out:
#   Category  Age Gender  ALB_Level  ALP_Level  ALT_Level  AST_Level  \
# 0   Normal   32      m       38.5       52.5        7.7       22.1
# 1   Normal   32      m       38.5       70.3       18.0       24.7
# 2   Normal   32      m       46.9       74.7       36.2       52.6
# 3   Normal   32      m       43.2       52.0       30.6       22.6
# 4   Normal   32      m       39.2       74.1       32.6       24.8
#
#    Liver_Fibrosis_Score  Bilirubin_Level  CHOL   CREA  Alcohol_Consumption  \
# 0                   7.5             6.93  3.23  106.0                 12.1
# 1                   3.9            11.17  4.80   74.0                 15.6
# 2                   6.1             8.84  5.20   86.0                 33.2
# 3                  18.9             7.33  4.74   80.0                 33.8
# 4                   9.6             9.15  4.32   76.0                 29.9
#
#    Diabetes
# 0      69.0
# 1      76.5
# 2      79.3
# 3      75.7
# 4      68.7

# %%
df.columns
# Out:
# Index(['Category', 'Age', 'Gender', 'ALB_Level', 'ALP_Level', 'ALT_Level',
#        'AST_Level', 'Liver_Fibrosis_Score', 'Bilirubin_Level', 'CHOL', 'CREA',
#        'Alcohol_Consumption', 'Diabetes'],
#       dtype='object')

# %%
plt.figure(figsize=(12,7))
sns.countplot(x='Age',data=df)
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
plt.figure(figsize=(15,5))

plt.subplot(1,2,1)
plt.hist(df['Age'],color='red')

plt.subplot(1,2,2)
plt.hist(df['ALP_Level'],color='blue')
# Out:
# (array([137., 399.,  53.,   5.,   2.,   0.,   0.,   0.,   0.,   1.]),
#  array([ 11.3 ,  51.83,  92.36, 132.89, 173.42, 213.95, 254.48, 295.01,
#         335.54, 376.07, 416.6 ]),
#  <BarContainer object of 10 artists>)

# %%
df.hist(figsize=(15,55),layout=(15,4), color='ORANGE')
plt.show()

# %%
df['Age'].hist(figsize=(10,5),color='yellow')
# Out:
# <Axes: >

# %%
plt.boxplot(df['ALP_Level'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1b254059130>,
#   <matplotlib.lines.Line2D at 0x1b2540593d0>],
#  'caps': [<matplotlib.lines.Line2D at 0x1b254059670>,
#   <matplotlib.lines.Line2D at 0x1b254059910>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1b254273e50>],
#  'medians': [<matplotlib.lines.Line2D at 0x1b254059bb0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1b254059e50>],
#  'means': []}

# %%
df['Liver_Fibrosis_Score'].plot(kind='density')
# Out:
# <Axes: ylabel='Density'>

# %%
sns.displot(df['ALT_Level'], color='purple') 
# barplot, boxenplot, boxplot, countplot, displot, distplot, ecdfplot, histplot, kdeplot, pointplot, violinplot, stripplot

# %%
sns.displot(df['ALP_Level'], color='coral') # residplot, scatterplot

# %%
sns.pairplot(df)

# %%
fig, ax = plt.subplots(figsize=(20,15))
sns.heatmap(df.corr(),annot = True, fmt='0.2%',cmap = 'autumn',ax=ax)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 2
#       1 fig, ax = plt.subplots(figsize=(20,15))
# ----> 2 sns.heatmap(df.corr(),annot = True, fmt='0.2%',cmap = 'autumn',ax=ax)
#
# File ~\anaconda3\envs\env\lib\site-packages\pandas\core\frame.py:11022, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11020 cols = data.columns
#   11021 idx = cols.copy()
# > 11022 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11024 if method == "pearson":
#   11025     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~\anaconda3\envs\env\lib\site-packages\pandas\core\frame.py:1981, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1979 if dtype is not None:
#    1980     dtype = np.dtype(dtype)
# -> 1981 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1982 if result.dtype is not dtype:
#    1983     result = np.array(result, dtype=dtype, copy=False)
#
# File ~\anaconda3\envs\env\lib\site-packages\pandas\core\internals\managers.py:1693, in BlockManager.as_array(self, dtype, copy, na_value)
#    1691         arr.flags.writeable = False
#    1692 else:
# -> 1693     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1694     # The underlying data was copied within _interleave, so no need
#    1695     # to further copy if copy=True or setting na_value
#    1697 if na_value is lib.no_default:
#
# File ~\anaconda3\envs\env\lib\site-packages\pandas\core\internals\managers.py:1752, in BlockManager._interleave(self, dtype, na_value)
#    1750     else:
#    1751         arr = blk.get_values(dtype)
# -> 1752     result[rl.indexer] = arr
#    1753     itemmask[rl.indexer] = 1
#    1755 if not itemmask.all():
#
# ValueError: could not convert string to float: 'Normal'

# %%
def plot(df, variable):
    dataframe_pie = df[variable].value_counts()
    ax = dataframe_pie.plot.pie(figsize=(9,9), autopct='%1.2f%%', fontsize = 10)
    ax.set_title(variable + ' \n', fontsize = 10)
    return np.round(dataframe_pie/df.shape[0]*100,2)

plot(df, 'Diagnosis')
