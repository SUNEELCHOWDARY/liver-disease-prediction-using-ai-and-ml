# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import tensorflow
import tensorflow as tf
print(tf.__version__)

import keras
import keras.backend as K
from keras.models import Model
from keras.layers import Input, Dense, Conv2D, Conv3D, DepthwiseConv2D, SeparableConv2D, Conv3DTranspose
from keras.layers import Flatten, MaxPool2D, AvgPool2D, GlobalAvgPool2D, UpSampling2D, BatchNormalization
from keras.layers import Concatenate, Add, Dropout, ReLU, Lambda, Activation, LeakyReLU, PReLU



from time import time
import numpy as np

from keras.callbacks import ModelCheckpoint
from tensorflow.keras.callbacks import EarlyStopping

import warnings
warnings.filterwarnings('ignore')
# Out:
# 2.14.1

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train=ImageDataGenerator(rescale=1./255,shear_range=0.2,zoom_range=0.2,horizontal_flip=True,validation_split = 0.2)
train_data=train.flow_from_directory(directory = 'dataset/TRAIN',target_size=(224,224),
                                     batch_size=32,class_mode='categorical')
# Out:
# Found 2000 images belonging to 5 classes.

# %%
test=ImageDataGenerator(rescale=1./255)
test_data=test.flow_from_directory(directory = 'dataset/TEST',target_size=(224,224),
                                   batch_size=32,class_mode='categorical')
# Out:
# Found 1000 images belonging to 5 classes.

# %%
def shufflenet(input_shape, n_classes, g=8):
  channels = 384, 769, 1536
  repetitions = 3, 7, 3
  
  def ch_shuffle(x, g):
#     1 2 3 4 5 6 7 8 9 -reshape-> 1 2 3 -permute dims-> 1 4 7 -reshape-> 1 4 7 2 5 8 3 6 9
#                                  4 5 6                 2 5 8
#                                  7 8 9                 3 6 9
    
    _, w, h, ch = K.int_shape(x)
    ch_g = ch // g
    
    def shuffle_op(x):
      x = K.reshape(x, [-1, w, h, ch_g, g])
      x = K.permute_dimensions(x, [0, 1, 2, 4, 3])
      x = K.reshape(x, [-1, w, h, ch])
      return x
    
    x = Lambda(shuffle_op)(x)
    return x
    
  
  def gconv(tensor, ch, g):
    _, _, _, in_ch = K.int_shape(tensor)
    ch_g = in_ch // g
    out_ch = ch // g
    group = []
    
    for i in range(g):
#       x = tensor[:, :, :, i*ch_g:(i+1)*ch_g]
      x = Lambda(lambda x: x[:, :, :, i*ch_g: (i+1)*ch_g])(tensor)
      x = Conv2D(out_ch, 1)(x)
      group.append(x)
    
    x = Concatenate()(group)
    return x
  
  
  def shufflenet_block(tensor, ch, s, g):
    x = gconv(tensor, ch // 4, g)
    x = BatchNormalization()(x)
    x = ReLU()(x)
    x = ch_shuffle(x, g)
    x = DepthwiseConv2D(3, strides=s, padding='same')(x)
    x = BatchNormalization()(x)
    x = gconv(x, ch if s==1 else ch-K.int_shape(tensor)[-1], g)
    x = BatchNormalization()(x)
    
    if s == 1:
      x = Add()([tensor, x])
    else:
      avg = AvgPool2D(3, strides=2, padding='same')(tensor)
      x = Concatenate()([avg, x])
    
    output = ReLU()(x)
    return output
  
  
  def stage(x, ch, r, g):
    x = shufflenet_block(x, ch, 2, g)
    
    for i in range(r):
      x = shufflenet_block(x, ch, 1, g)
      
    return x
  
  input = Input(input_shape)
  
  x = Conv2D(24, 3, strides=2, padding='same')(input)
  x = BatchNormalization()(x)
  x = ReLU()(x)
  x = MaxPool2D(3, strides=2, padding='same')(x)
  
  for ch, r in zip(channels, repetitions):
    x = stage(x, ch, r, g)
    
  x = GlobalAvgPool2D()(x)
  output = Dense(n_classes, activation='softmax')(x)
  
  model = Model(input, output)
  model.compile(optimizer='Adam',loss='categorical_crossentropy',metrics=['accuracy',tensorflow.keras.metrics.Precision()])
  return model
     

input_shape = 224, 224, 3
n_classes = 5

K.clear_session()
model = shufflenet(input_shape, n_classes)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  conv2d (Conv2D)             (None, 112, 112, 24)         672       ['input_1[0][0]']
#
#  batch_normalization (Batch  (None, 112, 112, 24)         96        ['conv2d[0][0]']
#  Normalization)
#
#  re_lu (ReLU)                (None, 112, 112, 24)         0         ['batch_normalization[0][0]']
#
#  max_pooling2d (MaxPooling2  (None, 56, 56, 24)           0         ['re_lu[0][0]']
#  D)
#
#  lambda (Lambda)             (None, 56, 56, 3)            0         ['max_pooling2d[0][0]']
#
#  lambda_1 (Lambda)           (None, 56, 56, 3)            0         ['max_pooling2d[0][0]']
#
#  lambda_2 (Lambda)           (None, 56, 56, 3)            0         ['max_pooling2d[0][0]']
#
#  lambda_3 (Lambda)           (None, 56, 56, 3)            0         ['max_pooling2d[0][0]']
#
#  lambda_4 (Lambda)           (None, 56, 56, 3)            0         ['max_pooling2d[0][0]']
#
#  lambda_5 (Lambda)           (None, 56, 56, 3)            0         ['max_pooling2d[0][0]']
#
#  lambda_6 (Lambda)           (None, 56, 56, 3)            0         ['max_pooling2d[0][0]']
#
#  lambda_7 (Lambda)           (None, 56, 56, 3)            0         ['max_pooling2d[0][0]']
#
#  conv2d_1 (Conv2D)           (None, 56, 56, 12)           48        ['lambda[0][0]']
#
#  conv2d_2 (Conv2D)           (None, 56, 56, 12)           48        ['lambda_1[0][0]']
#
#  conv2d_3 (Conv2D)           (None, 56, 56, 12)           48        ['lambda_2[0][0]']
#
#  conv2d_4 (Conv2D)           (None, 56, 56, 12)           48        ['lambda_3[0][0]']
#
#  conv2d_5 (Conv2D)           (None, 56, 56, 12)           48        ['lambda_4[0][0]']
#
#  conv2d_6 (Conv2D)           (None, 56, 56, 12)           48        ['lambda_5[0][0]']
#
#  conv2d_7 (Conv2D)           (None, 56, 56, 12)           48        ['lambda_6[0][0]']
#
#  conv2d_8 (Conv2D)           (None, 56, 56, 12)           48        ['lambda_7[0][0]']
#
#  concatenate (Concatenate)   (None, 56, 56, 96)           0         ['conv2d_1[0][0]',
#                                                                      'conv2d_2[0][0]',
#                                                                      'conv2d_3[0][0]',
#                                                                      'conv2d_4[0][0]',
#                                                                      'conv2d_5[0][0]',
#                                                                      'conv2d_6[0][0]',
#                                                                      'conv2d_7[0][0]',
#                                                                      'conv2d_8[0][0]']
#
#  batch_normalization_1 (Bat  (None, 56, 56, 96)           384       ['concatenate[0][0]']
#  chNormalization)
#
#  re_lu_1 (ReLU)              (None, 56, 56, 96)           0         ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  lambda_8 (Lambda)           (None, 56, 56, 96)           0         ['re_lu_1[0][0]']
#
#  depthwise_conv2d (Depthwis  (None, 28, 28, 96)           960       ['lambda_8[0][0]']
#  eConv2D)
#
#  batch_normalization_2 (Bat  (None, 28, 28, 96)           384       ['depthwise_conv2d[0][0]']
#  chNormalization)
#
#  lambda_9 (Lambda)           (None, 28, 28, 12)           0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  lambda_10 (Lambda)          (None, 28, 28, 12)           0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  lambda_11 (Lambda)          (None, 28, 28, 12)           0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  lambda_12 (Lambda)          (None, 28, 28, 12)           0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  lambda_13 (Lambda)          (None, 28, 28, 12)           0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  lambda_14 (Lambda)          (None, 28, 28, 12)           0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  lambda_15 (Lambda)          (None, 28, 28, 12)           0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  lambda_16 (Lambda)          (None, 28, 28, 12)           0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  conv2d_9 (Conv2D)           (None, 28, 28, 45)           585       ['lambda_9[0][0]']
#
#  conv2d_10 (Conv2D)          (None, 28, 28, 45)           585       ['lambda_10[0][0]']
#
#  conv2d_11 (Conv2D)          (None, 28, 28, 45)           585       ['lambda_11[0][0]']
#
#  conv2d_12 (Conv2D)          (None, 28, 28, 45)           585       ['lambda_12[0][0]']
#
#  conv2d_13 (Conv2D)          (None, 28, 28, 45)           585       ['lambda_13[0][0]']
#
#  conv2d_14 (Conv2D)          (None, 28, 28, 45)           585       ['lambda_14[0][0]']
#
#  conv2d_15 (Conv2D)          (None, 28, 28, 45)           585       ['lambda_15[0][0]']
#
#  conv2d_16 (Conv2D)          (None, 28, 28, 45)           585       ['lambda_16[0][0]']
#
#  concatenate_1 (Concatenate  (None, 28, 28, 360)          0         ['conv2d_9[0][0]',
#  )                                                                   'conv2d_10[0][0]',
#                                                                      'conv2d_11[0][0]',
#                                                                      'conv2d_12[0][0]',
#                                                                      'conv2d_13[0][0]',
#                                                                      'conv2d_14[0][0]',
#                                                                      'conv2d_15[0][0]',
#                                                                      'conv2d_16[0][0]']
#
#  average_pooling2d (Average  (None, 28, 28, 24)           0         ['max_pooling2d[0][0]']
#  Pooling2D)
#
#  batch_normalization_3 (Bat  (None, 28, 28, 360)          1440      ['concatenate_1[0][0]']
#  chNormalization)
#
#  concatenate_2 (Concatenate  (None, 28, 28, 384)          0         ['average_pooling2d[0][0]',
#  )                                                                   'batch_normalization_3[0][0]'
#                                                                     ]
#
#  re_lu_2 (ReLU)              (None, 28, 28, 384)          0         ['concatenate_2[0][0]']
#
#  lambda_17 (Lambda)          (None, 28, 28, 48)           0         ['re_lu_2[0][0]']
#
#  lambda_18 (Lambda)          (None, 28, 28, 48)           0         ['re_lu_2[0][0]']
#
#  lambda_19 (Lambda)          (None, 28, 28, 48)           0         ['re_lu_2[0][0]']
#
#  lambda_20 (Lambda)          (None, 28, 28, 48)           0         ['re_lu_2[0][0]']
#
#  lambda_21 (Lambda)          (None, 28, 28, 48)           0         ['re_lu_2[0][0]']
#
#  lambda_22 (Lambda)          (None, 28, 28, 48)           0         ['re_lu_2[0][0]']
#
#  lambda_23 (Lambda)          (None, 28, 28, 48)           0         ['re_lu_2[0][0]']
#
#  lambda_24 (Lambda)          (None, 28, 28, 48)           0         ['re_lu_2[0][0]']
#
#  conv2d_17 (Conv2D)          (None, 28, 28, 12)           588       ['lambda_17[0][0]']
#
#  conv2d_18 (Conv2D)          (None, 28, 28, 12)           588       ['lambda_18[0][0]']
#
#  conv2d_19 (Conv2D)          (None, 28, 28, 12)           588       ['lambda_19[0][0]']
#
#  conv2d_20 (Conv2D)          (None, 28, 28, 12)           588       ['lambda_20[0][0]']
#
#  conv2d_21 (Conv2D)          (None, 28, 28, 12)           588       ['lambda_21[0][0]']
#
#  conv2d_22 (Conv2D)          (None, 28, 28, 12)           588       ['lambda_22[0][0]']
#
#  conv2d_23 (Conv2D)          (None, 28, 28, 12)           588       ['lambda_23[0][0]']
#
#  conv2d_24 (Conv2D)          (None, 28, 28, 12)           588       ['lambda_24[0][0]']
#
#  concatenate_3 (Concatenate  (None, 28, 28, 96)           0         ['conv2d_17[0][0]',
#  )                                                                   'conv2d_18[0][0]',
#                                                                      'conv2d_19[0][0]',
#                                                                      'conv2d_20[0][0]',
#                                                                      'conv2d_21[0][0]',
#                                                                      'conv2d_22[0][0]',
#                                                                      'conv2d_23[0][0]',
#                                                                      'conv2d_24[0][0]']
#
#  batch_normalization_4 (Bat  (None, 28, 28, 96)           384       ['concatenate_3[0][0]']
#  chNormalization)
#
#  re_lu_3 (ReLU)              (None, 28, 28, 96)           0         ['batch_normalization_4[0][0]'
#                                                                     ]
#
#  lambda_25 (Lambda)          (None, 28, 28, 96)           0         ['re_lu_3[0][0]']
#
#  depthwise_conv2d_1 (Depthw  (None, 28, 28, 96)           960       ['lambda_25[0][0]']
#  iseConv2D)
#
#  batch_normalization_5 (Bat  (None, 28, 28, 96)           384       ['depthwise_conv2d_1[0][0]']
#  chNormalization)
#
#  lambda_26 (Lambda)          (None, 28, 28, 12)           0         ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  lambda_27 (Lambda)          (None, 28, 28, 12)           0         ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  lambda_28 (Lambda)          (None, 28, 28, 12)           0         ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  lambda_29 (Lambda)          (None, 28, 28, 12)           0         ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  lambda_30 (Lambda)          (None, 28, 28, 12)           0         ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  lambda_31 (Lambda)          (None, 28, 28, 12)           0         ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  lambda_32 (Lambda)          (None, 28, 28, 12)           0         ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  lambda_33 (Lambda)          (None, 28, 28, 12)           0         ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  conv2d_25 (Conv2D)          (None, 28, 28, 48)           624       ['lambda_26[0][0]']
#
#  conv2d_26 (Conv2D)          (None, 28, 28, 48)           624       ['lambda_27[0][0]']
#
#  conv2d_27 (Conv2D)          (None, 28, 28, 48)           624       ['lambda_28[0][0]']
#
#  conv2d_28 (Conv2D)          (None, 28, 28, 48)           624       ['lambda_29[0][0]']
#
#  conv2d_29 (Conv2D)          (None, 28, 28, 48)           624       ['lambda_30[0][0]']
#
#  conv2d_30 (Conv2D)          (None, 28, 28, 48)           624       ['lambda_31[0][0]']
#
#  conv2d_31 (Conv2D)          (None, 28, 28, 48)           624       ['lambda_32[0][0]']
#
#  conv2d_32 (Conv2D)          (None, 28, 28, 48)           624       ['lambda_33[0][0]']
#
#  concatenate_4 (Concatenate  (None, 28, 28, 384)          0         ['conv2d_25[0][0]',
#  )                                                                   'conv2d_26[0][0]',
#                                                                      'conv2d_27[0][0]',
#                                                                      'conv2d_28[0][0]',
#                                                                      'conv2d_29[0][0]',
#                                                                      'conv2d_30[0][0]',
#                                                                      'conv2d_31[0][0]',
#                                                                      'conv2d_32[0][0]']
#
#  batch_normalization_6 (Bat  (None, 28, 28, 384)          1536      ['concatenate_4[0][0]']
#  chNormalization)
#
#  add (Add)                   (None, 28, 28, 384)          0         ['re_lu_2[0][0]',
#                                                                      'batch_normalization_6[0][0]'
#                                                                     ]
#
#  re_lu_4 (ReLU)              (None, 28, 28, 384)          0         ['add[0][0]']
#
#  lambda_34 (Lambda)          (None, 28, 28, 48)           0         ['re_lu_4[0][0]']
#
#  lambda_35 (Lambda)          (None, 28, 28, 48)           0         ['re_lu_4[0][0]']
#
#  lambda_36 (Lambda)          (None, 28, 28, 48)           0         ['re_lu_4[0][0]']
#
#  lambda_37 (Lambda)          (None, 28, 28, 48)           0         ['re_lu_4[0][0]']
#
#  lambda_38 (Lambda)          (None, 28, 28, 48)           0         ['re_lu_4[0][0]']
#
#  lambda_39 (Lambda)          (None, 28, 28, 48)           0         ['re_lu_4[0][0]']
#
#  lambda_40 (Lambda)          (None, 28, 28, 48)           0         ['re_lu_4[0][0]']
#
#  lambda_41 (Lambda)          (None, 28, 28, 48)           0         ['re_lu_4[0][0]']
#
#  conv2d_33 (Conv2D)          (None, 28, 28, 12)           588       ['lambda_34[0][0]']
#
#  conv2d_34 (Conv2D)          (None, 28, 28, 12)           588       ['lambda_35[0][0]']
#
#  conv2d_35 (Conv2D)          (None, 28, 28, 12)           588       ['lambda_36[0][0]']
#
#  conv2d_36 (Conv2D)          (None, 28, 28, 12)           588       ['lambda_37[0][0]']
#
#  conv2d_37 (Conv2D)          (None, 28, 28, 12)           588       ['lambda_38[0][0]']
#
#  conv2d_38 (Conv2D)          (None, 28, 28, 12)           588       ['lambda_39[0][0]']
#
#  conv2d_39 (Conv2D)          (None, 28, 28, 12)           588       ['lambda_40[0][0]']
#
#  conv2d_40 (Conv2D)          (None, 28, 28, 12)           588       ['lambda_41[0][0]']
#
#  concatenate_5 (Concatenate  (None, 28, 28, 96)           0         ['conv2d_33[0][0]',
#  )                                                                   'conv2d_34[0][0]',
#                                                                      'conv2d_35[0][0]',
#                                                                      'conv2d_36[0][0]',
#                                                                      'conv2d_37[0][0]',
#                                                                      'conv2d_38[0][0]',
#                                                                      'conv2d_39[0][0]',
#                                                                      'conv2d_40[0][0]']
#
#  batch_normalization_7 (Bat  (None, 28, 28, 96)           384       ['concatenate_5[0][0]']
#  chNormalization)
#
#  re_lu_5 (ReLU)              (None, 28, 28, 96)           0         ['batch_normalization_7[0][0]'
#                                                                     ]
#
#  lambda_42 (Lambda)          (None, 28, 28, 96)           0         ['re_lu_5[0][0]']
#
#  depthwise_conv2d_2 (Depthw  (None, 28, 28, 96)           960       ['lambda_42[0][0]']
#  iseConv2D)
#
#  batch_normalization_8 (Bat  (None, 28, 28, 96)           384       ['depthwise_conv2d_2[0][0]']
#  chNormalization)
#
#  lambda_43 (Lambda)          (None, 28, 28, 12)           0         ['batch_normalization_8[0][0]'
#                                                                     ]
#
#  lambda_44 (Lambda)          (None, 28, 28, 12)           0         ['batch_normalization_8[0][0]'
#                                                                     ]
#
#  lambda_45 (Lambda)          (None, 28, 28, 12)           0         ['batch_normalization_8[0][0]'
#                                                                     ]
#
#  lambda_46 (Lambda)          (None, 28, 28, 12)           0         ['batch_normalization_8[0][0]'
#                                                                     ]
#
#  lambda_47 (Lambda)          (None, 28, 28, 12)           0         ['batch_normalization_8[0][0]'
#                                                                     ]
#
#  lambda_48 (Lambda)          (None, 28, 28, 12)           0         ['batch_normalization_8[0][0]'
#                                                                     ]
#
#  lambda_49 (Lambda)          (None, 28, 28, 12)           0         ['batch_normalization_8[0][0]'
#                                                                     ]
#
#  lambda_50 (Lambda)          (None, 28, 28, 12)           0         ['batch_normalization_8[0][0]'
#                                                                     ]
#
#  conv2d_41 (Conv2D)          (None, 28, 28, 48)           624       ['lambda_43[0][0]']
#
#  conv2d_42 (Conv2D)          (None, 28, 28, 48)           624       ['lambda_44[0][0]']
#
#  conv2d_43 (Conv2D)          (None, 28, 28, 48)           624       ['lambda_45[0][0]']
#
#  conv2d_44 (Conv2D)          (None, 28, 28, 48)           624       ['lambda_46[0][0]']
#
#  conv2d_45 (Conv2D)          (None, 28, 28, 48)           624       ['lambda_47[0][0]']
#
#  conv2d_46 (Conv2D)          (None, 28, 28, 48)           624       ['lambda_48[0][0]']
#
#  conv2d_47 (Conv2D)          (None, 28, 28, 48)           624       ['lambda_49[0][0]']
#
#  conv2d_48 (Conv2D)          (None, 28, 28, 48)           624       ['lambda_50[0][0]']
#
#  concatenate_6 (Concatenate  (None, 28, 28, 384)          0         ['conv2d_41[0][0]',
#  )                                                                   'conv2d_42[0][0]',
#                                                                      'conv2d_43[0][0]',
#                                                                      'conv2d_44[0][0]',
#                                                                      'conv2d_45[0][0]',
#                                                                      'conv2d_46[0][0]',
#                                                                      'conv2d_47[0][0]',
#                                                                      'conv2d_48[0][0]']
#
#  batch_normalization_9 (Bat  (None, 28, 28, 384)          1536      ['concatenate_6[0][0]']
#  chNormalization)
#
#  add_1 (Add)                 (None, 28, 28, 384)          0         ['re_lu_4[0][0]',
#                                                                      'batch_normalization_9[0][0]'
#                                                                     ]
#
#  re_lu_6 (ReLU)              (None, 28, 28, 384)          0         ['add_1[0][0]']
#
#  lambda_51 (Lambda)          (None, 28, 28, 48)           0         ['re_lu_6[0][0]']
#
#  lambda_52 (Lambda)          (None, 28, 28, 48)           0         ['re_lu_6[0][0]']
#
#  lambda_53 (Lambda)          (None, 28, 28, 48)           0         ['re_lu_6[0][0]']
#
#  lambda_54 (Lambda)          (None, 28, 28, 48)           0         ['re_lu_6[0][0]']
#
#  lambda_55 (Lambda)          (None, 28, 28, 48)           0         ['re_lu_6[0][0]']
#
#  lambda_56 (Lambda)          (None, 28, 28, 48)           0         ['re_lu_6[0][0]']
#
#  lambda_57 (Lambda)          (None, 28, 28, 48)           0         ['re_lu_6[0][0]']
#
#  lambda_58 (Lambda)          (None, 28, 28, 48)           0         ['re_lu_6[0][0]']
#
#  conv2d_49 (Conv2D)          (None, 28, 28, 12)           588       ['lambda_51[0][0]']
#
#  conv2d_50 (Conv2D)          (None, 28, 28, 12)           588       ['lambda_52[0][0]']
#
#  conv2d_51 (Conv2D)          (None, 28, 28, 12)           588       ['lambda_53[0][0]']
#
#  conv2d_52 (Conv2D)          (None, 28, 28, 12)           588       ['lambda_54[0][0]']
#
#  conv2d_53 (Conv2D)          (None, 28, 28, 12)           588       ['lambda_55[0][0]']
#
#  conv2d_54 (Conv2D)          (None, 28, 28, 12)           588       ['lambda_56[0][0]']
#
#  conv2d_55 (Conv2D)          (None, 28, 28, 12)           588       ['lambda_57[0][0]']
#
#  conv2d_56 (Conv2D)          (None, 28, 28, 12)           588       ['lambda_58[0][0]']
#
#  concatenate_7 (Concatenate  (None, 28, 28, 96)           0         ['conv2d_49[0][0]',
#  )                                                                   'conv2d_50[0][0]',
#                                                                      'conv2d_51[0][0]',
#                                                                      'conv2d_52[0][0]',
#                                                                      'conv2d_53[0][0]',
#                                                                      'conv2d_54[0][0]',
#                                                                      'conv2d_55[0][0]',
#                                                                      'conv2d_56[0][0]']
#
#  batch_normalization_10 (Ba  (None, 28, 28, 96)           384       ['concatenate_7[0][0]']
#  tchNormalization)
#
#  re_lu_7 (ReLU)              (None, 28, 28, 96)           0         ['batch_normalization_10[0][0]
#                                                                     ']
#
#  lambda_59 (Lambda)          (None, 28, 28, 96)           0         ['re_lu_7[0][0]']
#
#  depthwise_conv2d_3 (Depthw  (None, 28, 28, 96)           960       ['lambda_59[0][0]']
#  iseConv2D)
#
#  batch_normalization_11 (Ba  (None, 28, 28, 96)           384       ['depthwise_conv2d_3[0][0]']
#  tchNormalization)
#
#  lambda_60 (Lambda)          (None, 28, 28, 12)           0         ['batch_normalization_11[0][0]
#                                                                     ']
#
#  lambda_61 (Lambda)          (None, 28, 28, 12)           0         ['batch_normalization_11[0][0]
#                                                                     ']
#
#  lambda_62 (Lambda)          (None, 28, 28, 12)           0         ['batch_normalization_11[0][0]
#                                                                     ']
#
#  lambda_63 (Lambda)          (None, 28, 28, 12)           0         ['batch_normalization_11[0][0]
#                                                                     ']
#
#  lambda_64 (Lambda)          (None, 28, 28, 12)           0         ['batch_normalization_11[0][0]
#                                                                     ']
#
#  lambda_65 (Lambda)          (None, 28, 28, 12)           0         ['batch_normalization_11[0][0]
#                                                                     ']
#
#  lambda_66 (Lambda)          (None, 28, 28, 12)           0         ['batch_normalization_11[0][0]
#                                                                     ']
#
#  lambda_67 (Lambda)          (None, 28, 28, 12)           0         ['batch_normalization_11[0][0]
#                                                                     ']
#
#  conv2d_57 (Conv2D)          (None, 28, 28, 48)           624       ['lambda_60[0][0]']
#
#  conv2d_58 (Conv2D)          (None, 28, 28, 48)           624       ['lambda_61[0][0]']
#
#  conv2d_59 (Conv2D)          (None, 28, 28, 48)           624       ['lambda_62[0][0]']
#
#  conv2d_60 (Conv2D)          (None, 28, 28, 48)           624       ['lambda_63[0][0]']
#
#  conv2d_61 (Conv2D)          (None, 28, 28, 48)           624       ['lambda_64[0][0]']
#
#  conv2d_62 (Conv2D)          (None, 28, 28, 48)           624       ['lambda_65[0][0]']
#
#  conv2d_63 (Conv2D)          (None, 28, 28, 48)           624       ['lambda_66[0][0]']
#
#  conv2d_64 (Conv2D)          (None, 28, 28, 48)           624       ['lambda_67[0][0]']
#
#  concatenate_8 (Concatenate  (None, 28, 28, 384)          0         ['conv2d_57[0][0]',
#  )                                                                   'conv2d_58[0][0]',
#                                                                      'conv2d_59[0][0]',
#                                                                      'conv2d_60[0][0]',
#                                                                      'conv2d_61[0][0]',
#                                                                      'conv2d_62[0][0]',
#                                                                      'conv2d_63[0][0]',
#                                                                      'conv2d_64[0][0]']
#
#  batch_normalization_12 (Ba  (None, 28, 28, 384)          1536      ['concatenate_8[0][0]']
#  tchNormalization)
#
#  add_2 (Add)                 (None, 28, 28, 384)          0         ['re_lu_6[0][0]',
#                                                                      'batch_normalization_12[0][0]
#                                                                     ']
#
#  re_lu_8 (ReLU)              (None, 28, 28, 384)          0         ['add_2[0][0]']
#
#  lambda_68 (Lambda)          (None, 28, 28, 48)           0         ['re_lu_8[0][0]']
#
#  lambda_69 (Lambda)          (None, 28, 28, 48)           0         ['re_lu_8[0][0]']
#
#  lambda_70 (Lambda)          (None, 28, 28, 48)           0         ['re_lu_8[0][0]']
#
#  lambda_71 (Lambda)          (None, 28, 28, 48)           0         ['re_lu_8[0][0]']
#
#  lambda_72 (Lambda)          (None, 28, 28, 48)           0         ['re_lu_8[0][0]']
#
#  lambda_73 (Lambda)          (None, 28, 28, 48)           0         ['re_lu_8[0][0]']
#
#  lambda_74 (Lambda)          (None, 28, 28, 48)           0         ['re_lu_8[0][0]']
#
# ...
#  ormalization)
#
#  lambda_247 (Lambda)            (None, 7, 7, 48)     0           ['batch_normalization_44[0][0]']
#
#  lambda_248 (Lambda)            (None, 7, 7, 48)     0           ['batch_normalization_44[0][0]']
#
#  lambda_249 (Lambda)            (None, 7, 7, 48)     0           ['batch_normalization_44[0][0]']
#
#  lambda_250 (Lambda)            (None, 7, 7, 48)     0           ['batch_normalization_44[0][0]']
#
#  lambda_251 (Lambda)            (None, 7, 7, 48)     0           ['batch_normalization_44[0][0]']
#
#  lambda_252 (Lambda)            (None, 7, 7, 48)     0           ['batch_normalization_44[0][0]']
#
#  lambda_253 (Lambda)            (None, 7, 7, 48)     0           ['batch_normalization_44[0][0]']
#
#  lambda_254 (Lambda)            (None, 7, 7, 48)     0           ['batch_normalization_44[0][0]']
#
#  conv2d_233 (Conv2D)            (None, 7, 7, 192)    9408        ['lambda_247[0][0]']
#
#  conv2d_234 (Conv2D)            (None, 7, 7, 192)    9408        ['lambda_248[0][0]']
#
#  conv2d_235 (Conv2D)            (None, 7, 7, 192)    9408        ['lambda_249[0][0]']
#
#  conv2d_236 (Conv2D)            (None, 7, 7, 192)    9408        ['lambda_250[0][0]']
#
#  conv2d_237 (Conv2D)            (None, 7, 7, 192)    9408        ['lambda_251[0][0]']
#
#  conv2d_238 (Conv2D)            (None, 7, 7, 192)    9408        ['lambda_252[0][0]']
#
#  conv2d_239 (Conv2D)            (None, 7, 7, 192)    9408        ['lambda_253[0][0]']
#
#  conv2d_240 (Conv2D)            (None, 7, 7, 192)    9408        ['lambda_254[0][0]']
#
#  concatenate_32 (Concatenate)   (None, 7, 7, 1536)   0           ['conv2d_233[0][0]',
#                                                                   'conv2d_234[0][0]',
#                                                                   'conv2d_235[0][0]',
#                                                                   'conv2d_236[0][0]',
#                                                                   'conv2d_237[0][0]',
#                                                                   'conv2d_238[0][0]',
#                                                                   'conv2d_239[0][0]',
#                                                                   'conv2d_240[0][0]']
#
#  batch_normalization_45 (BatchN  (None, 7, 7, 1536)  6144        ['concatenate_32[0][0]']
#  ormalization)
#
#  add_11 (Add)                   (None, 7, 7, 1536)   0           ['re_lu_28[0][0]',
#                                                                   'batch_normalization_45[0][0]']
#
#  re_lu_30 (ReLU)                (None, 7, 7, 1536)   0           ['add_11[0][0]']
#
#  lambda_255 (Lambda)            (None, 7, 7, 192)    0           ['re_lu_30[0][0]']
#
#  lambda_256 (Lambda)            (None, 7, 7, 192)    0           ['re_lu_30[0][0]']
#
#  lambda_257 (Lambda)            (None, 7, 7, 192)    0           ['re_lu_30[0][0]']
#  lambda_258 (Lambda)            (None, 7, 7, 192)    0           ['re_lu_30[0][0]']
#
#  lambda_259 (Lambda)            (None, 7, 7, 192)    0           ['re_lu_30[0][0]']
#
#  lambda_260 (Lambda)            (None, 7, 7, 192)    0           ['re_lu_30[0][0]']
#
#  lambda_261 (Lambda)            (None, 7, 7, 192)    0           ['re_lu_30[0][0]']
#
#  lambda_262 (Lambda)            (None, 7, 7, 192)    0           ['re_lu_30[0][0]']
#
#  conv2d_241 (Conv2D)            (None, 7, 7, 48)     9264        ['lambda_255[0][0]']
#
#  conv2d_242 (Conv2D)            (None, 7, 7, 48)     9264        ['lambda_256[0][0]']
#
#  conv2d_243 (Conv2D)            (None, 7, 7, 48)     9264        ['lambda_257[0][0]']
#
#  conv2d_244 (Conv2D)            (None, 7, 7, 48)     9264        ['lambda_258[0][0]']
#
#  conv2d_245 (Conv2D)            (None, 7, 7, 48)     9264        ['lambda_259[0][0]']
#
#  conv2d_246 (Conv2D)            (None, 7, 7, 48)     9264        ['lambda_260[0][0]']
#
#  conv2d_247 (Conv2D)            (None, 7, 7, 48)     9264        ['lambda_261[0][0]']
#
#  conv2d_248 (Conv2D)            (None, 7, 7, 48)     9264        ['lambda_262[0][0]']
#
#  concatenate_33 (Concatenate)   (None, 7, 7, 384)    0           ['conv2d_241[0][0]',
#                                                                   'conv2d_242[0][0]',
#                                                                   'conv2d_243[0][0]',
#                                                                   'conv2d_244[0][0]',
#                                                                   'conv2d_245[0][0]',
#                                                                   'conv2d_246[0][0]',
#                                                                   'conv2d_247[0][0]',
#                                                                   'conv2d_248[0][0]']
#
#  batch_normalization_46 (BatchN  (None, 7, 7, 384)   1536        ['concatenate_33[0][0]']
#  ormalization)
#
#  re_lu_31 (ReLU)                (None, 7, 7, 384)    0           ['batch_normalization_46[0][0]']
#
#  lambda_263 (Lambda)            (None, 7, 7, 384)    0           ['re_lu_31[0][0]']
#
#  depthwise_conv2d_15 (Depthwise  (None, 7, 7, 384)   3840        ['lambda_263[0][0]']
#  Conv2D)
#
#  batch_normalization_47 (BatchN  (None, 7, 7, 384)   1536        ['depthwise_conv2d_15[0][0]']
#  ormalization)
#
#  lambda_264 (Lambda)            (None, 7, 7, 48)     0           ['batch_normalization_47[0][0]']
#
#  lambda_265 (Lambda)            (None, 7, 7, 48)     0           ['batch_normalization_47[0][0]']
#
#  lambda_266 (Lambda)            (None, 7, 7, 48)     0           ['batch_normalization_47[0][0]']
#
#  lambda_267 (Lambda)            (None, 7, 7, 48)     0           ['batch_normalization_47[0][0]']
#
#  lambda_268 (Lambda)            (None, 7, 7, 48)     0           ['batch_normalization_47[0][0]']
#
#  lambda_269 (Lambda)            (None, 7, 7, 48)     0           ['batch_normalization_47[0][0]']
#
#  lambda_270 (Lambda)            (None, 7, 7, 48)     0           ['batch_normalization_47[0][0]']
#
#  lambda_271 (Lambda)            (None, 7, 7, 48)     0           ['batch_normalization_47[0][0]']
#
#  conv2d_249 (Conv2D)            (None, 7, 7, 192)    9408        ['lambda_264[0][0]']
#
#  conv2d_250 (Conv2D)            (None, 7, 7, 192)    9408        ['lambda_265[0][0]']
#
#  conv2d_251 (Conv2D)            (None, 7, 7, 192)    9408        ['lambda_266[0][0]']
#
#  conv2d_252 (Conv2D)            (None, 7, 7, 192)    9408        ['lambda_267[0][0]']
#
#  conv2d_253 (Conv2D)            (None, 7, 7, 192)    9408        ['lambda_268[0][0]']
#
#  conv2d_254 (Conv2D)            (None, 7, 7, 192)    9408        ['lambda_269[0][0]']
#
#  conv2d_255 (Conv2D)            (None, 7, 7, 192)    9408        ['lambda_270[0][0]']
#
#  conv2d_256 (Conv2D)            (None, 7, 7, 192)    9408        ['lambda_271[0][0]']
#
#  concatenate_34 (Concatenate)   (None, 7, 7, 1536)   0           ['conv2d_249[0][0]',
#                                                                   'conv2d_250[0][0]',
#                                                                   'conv2d_251[0][0]',
#                                                                   'conv2d_252[0][0]',
#                                                                   'conv2d_253[0][0]',
#                                                                   'conv2d_254[0][0]',
#                                                                   'conv2d_255[0][0]',
#                                                                   'conv2d_256[0][0]']
#
#  batch_normalization_48 (BatchN  (None, 7, 7, 1536)  6144        ['concatenate_34[0][0]']
#  ormalization)
#
#  add_12 (Add)                   (None, 7, 7, 1536)   0           ['re_lu_30[0][0]',
#                                                                   'batch_normalization_48[0][0]']
#
#  re_lu_32 (ReLU)                (None, 7, 7, 1536)   0           ['add_12[0][0]']
#
#  global_average_pooling2d (Glob  (None, 1536)        0           ['re_lu_32[0][0]']
#  alAveragePooling2D)
#
#  dense (Dense)                  (None, 4)            6148        ['global_average_pooling2d[0][0]'
#                                                                  ]
#
# ==================================================================================================
# Total params: 960,652
# Trainable params: 921,484
# Non-trainable params: 39,168
# __________________________________________________________________________________________________

# %%
model_path = "model.h5"

from keras.callbacks import ModelCheckpoint

M = ModelCheckpoint(model_path, monitor='accuracy', verbose=1, save_best_only=True)

# %%
epochs = 100
batch_size = 32

# %%
#### Fitting the model
history = model.fit(
           train_data, steps_per_epoch=train_data.samples // batch_size, 
           epochs=epochs, 
           validation_data=test_data,validation_steps=test_data.samples // batch_size,
           callbacks=[M])
# Out:
# Epoch 1/100
# 62/62 [==============================] - ETA: 0s - loss: 1.5339 - accuracy: 0.3679 - precision: 0.4178
# Epoch 1: accuracy improved from -inf to 0.36789, saving model to model.h5
# 62/62 [==============================] - 395s 5s/step - loss: 1.5339 - accuracy: 0.3679 - precision: 0.4178 - val_loss: 1.6112 - val_accuracy: 0.2339 - val_precision: 0.0000e+00
# Epoch 2/100
# 62/62 [==============================] - ETA: 0s - loss: 1.3533 - accuracy: 0.3933 - precision: 0.4433
# Epoch 2: accuracy improved from 0.36789 to 0.39329, saving model to model.h5
# 62/62 [==============================] - 317s 5s/step - loss: 1.3533 - accuracy: 0.3933 - precision: 0.4433 - val_loss: 1.6170 - val_accuracy: 0.1996 - val_precision: 0.0000e+00
# Epoch 3/100
# 62/62 [==============================] - ETA: 0s - loss: 1.3112 - accuracy: 0.4096 - precision: 0.4518
# Epoch 3: accuracy improved from 0.39329 to 0.40955, saving model to model.h5
# 62/62 [==============================] - 328s 5s/step - loss: 1.3112 - accuracy: 0.4096 - precision: 0.4518 - val_loss: 1.6466 - val_accuracy: 0.2006 - val_precision: 0.0000e+00
# Epoch 4/100
# 62/62 [==============================] - ETA: 0s - loss: 1.3955 - accuracy: 0.4014 - precision: 0.4445
# Epoch 4: accuracy did not improve from 0.40955
# 62/62 [==============================] - 316s 5s/step - loss: 1.3955 - accuracy: 0.4014 - precision: 0.4445 - val_loss: 1.6974 - val_accuracy: 0.1996 - val_precision: 0.0000e+00
# Epoch 5/100
# 62/62 [==============================] - ETA: 0s - loss: 1.2722 - accuracy: 0.4411 - precision: 0.4904
# Epoch 5: accuracy improved from 0.40955 to 0.44106, saving model to model.h5
# 62/62 [==============================] - 354s 6s/step - loss: 1.2722 - accuracy: 0.4411 - precision: 0.4904 - val_loss: 1.7169 - val_accuracy: 0.2016 - val_precision: 0.0000e+00
# Epoch 6/100
# 62/62 [==============================] - ETA: 0s - loss: 1.2492 - accuracy: 0.4599 - precision: 0.5181
# Epoch 6: accuracy improved from 0.44106 to 0.45986, saving model to model.h5
# 62/62 [==============================] - 353s 6s/step - loss: 1.2492 - accuracy: 0.4599 - precision: 0.5181 - val_loss: 1.8224 - val_accuracy: 0.2016 - val_precision: 0.0000e+00
# Epoch 7/100
# 62/62 [==============================] - ETA: 0s - loss: 1.1605 - accuracy: 0.5091 - precision: 0.5630
# Epoch 7: accuracy improved from 0.45986 to 0.50915, saving model to model.h5
# 62/62 [==============================] - 422s 7s/step - loss: 1.1605 - accuracy: 0.5091 - precision: 0.5630 - val_loss: 2.0190 - val_accuracy: 0.1905 - val_precision: 0.2132
# Epoch 8/100
# 62/62 [==============================] - ETA: 0s - loss: 1.0525 - accuracy: 0.5437 - precision: 0.5932
# Epoch 8: accuracy improved from 0.50915 to 0.54370, saving model to model.h5
# 62/62 [==============================] - 330s 5s/step - loss: 1.0525 - accuracy: 0.5437 - precision: 0.5932 - val_loss: 2.4269 - val_accuracy: 0.1966 - val_precision: 0.1926
# Epoch 9/100
# 62/62 [==============================] - ETA: 0s - loss: 0.9746 - accuracy: 0.5986 - precision: 0.6429
# Epoch 9: accuracy improved from 0.54370 to 0.59858, saving model to model.h5
# 62/62 [==============================] - 356s 6s/step - loss: 0.9746 - accuracy: 0.5986 - precision: 0.6429 - val_loss: 2.2255 - val_accuracy: 0.2450 - val_precision: 0.2911
# Epoch 10/100
# 62/62 [==============================] - ETA: 0s - loss: 0.8619 - accuracy: 0.6372 - precision: 0.6959
# Epoch 10: accuracy improved from 0.59858 to 0.63720, saving model to model.h5
# 62/62 [==============================] - 365s 6s/step - loss: 0.8619 - accuracy: 0.6372 - precision: 0.6959 - val_loss: 2.1950 - val_accuracy: 0.2944 - val_precision: 0.2870
# Epoch 11/100
# 62/62 [==============================] - ETA: 0s - loss: 0.9188 - accuracy: 0.6138 - precision: 0.6528
# Epoch 11: accuracy did not improve from 0.63720
# 62/62 [==============================] - 328s 5s/step - loss: 0.9188 - accuracy: 0.6138 - precision: 0.6528 - val_loss: 1.6958 - val_accuracy: 0.4688 - val_precision: 0.4916
# Epoch 12/100
# 62/62 [==============================] - ETA: 0s - loss: 0.7645 - accuracy: 0.6941 - precision: 0.7339
# Epoch 12: accuracy improved from 0.63720 to 0.69411, saving model to model.h5
# 62/62 [==============================] - 361s 6s/step - loss: 0.7645 - accuracy: 0.6941 - precision: 0.7339 - val_loss: 1.2851 - val_accuracy: 0.5272 - val_precision: 0.5614
# Epoch 13/100
# 62/62 [==============================] - ETA: 0s - loss: 0.8155 - accuracy: 0.6585 - precision: 0.6995
# Epoch 13: accuracy did not improve from 0.69411
# 62/62 [==============================] - 356s 6s/step - loss: 0.8155 - accuracy: 0.6585 - precision: 0.6995 - val_loss: 2.4492 - val_accuracy: 0.3155 - val_precision: 0.3357
# Epoch 14/100
# 62/62 [==============================] - ETA: 0s - loss: 0.6830 - accuracy: 0.7154 - precision: 0.7583
# Epoch 14: accuracy improved from 0.69411 to 0.71545, saving model to model.h5
# 62/62 [==============================] - 366s 6s/step - loss: 0.6830 - accuracy: 0.7154 - precision: 0.7583 - val_loss: 1.4444 - val_accuracy: 0.5252 - val_precision: 0.5576
# Epoch 15/100
# 62/62 [==============================] - ETA: 0s - loss: 0.6351 - accuracy: 0.7368 - precision: 0.7780
# Epoch 15: accuracy improved from 0.71545 to 0.73679, saving model to model.h5
# 62/62 [==============================] - 333s 5s/step - loss: 0.6351 - accuracy: 0.7368 - precision: 0.7780 - val_loss: 1.7215 - val_accuracy: 0.4577 - val_precision: 0.5222
# Epoch 16/100
# 62/62 [==============================] - ETA: 0s - loss: 0.6907 - accuracy: 0.7236 - precision: 0.7608
# Epoch 16: accuracy did not improve from 0.73679
# 62/62 [==============================] - 311s 5s/step - loss: 0.6907 - accuracy: 0.7236 - precision: 0.7608 - val_loss: 5.2001 - val_accuracy: 0.2591 - val_precision: 0.2595
# Epoch 17/100
# 62/62 [==============================] - ETA: 0s - loss: 0.6388 - accuracy: 0.7393 - precision: 0.7778
# Epoch 17: accuracy improved from 0.73679 to 0.73933, saving model to model.h5
# 62/62 [==============================] - 305s 5s/step - loss: 0.6388 - accuracy: 0.7393 - precision: 0.7778 - val_loss: 3.2252 - val_accuracy: 0.3337 - val_precision: 0.3501
# Epoch 18/100
# 62/62 [==============================] - ETA: 0s - loss: 0.6224 - accuracy: 0.7566 - precision: 0.7892
# Epoch 18: accuracy improved from 0.73933 to 0.75661, saving model to model.h5
# 62/62 [==============================] - 342s 6s/step - loss: 0.6224 - accuracy: 0.7566 - precision: 0.7892 - val_loss: 2.0557 - val_accuracy: 0.3972 - val_precision: 0.4171
# Epoch 19/100
# 62/62 [==============================] - ETA: 0s - loss: 0.5190 - accuracy: 0.7988 - precision: 0.8305
# Epoch 19: accuracy improved from 0.75661 to 0.79878, saving model to model.h5
# 62/62 [==============================] - 325s 5s/step - loss: 0.5190 - accuracy: 0.7988 - precision: 0.8305 - val_loss: 1.4074 - val_accuracy: 0.5786 - val_precision: 0.5878
# Epoch 20/100
# 62/62 [==============================] - ETA: 0s - loss: 0.5004 - accuracy: 0.8059 - precision: 0.8377
# Epoch 20: accuracy improved from 0.79878 to 0.80589, saving model to model.h5
# 62/62 [==============================] - 336s 5s/step - loss: 0.5004 - accuracy: 0.8059 - precision: 0.8377 - val_loss: 5.8073 - val_accuracy: 0.3286 - val_precision: 0.3333
# Epoch 21/100
# 62/62 [==============================] - ETA: 0s - loss: 0.5363 - accuracy: 0.7835 - precision: 0.8078
# Epoch 21: accuracy did not improve from 0.80589
# 62/62 [==============================] - 326s 5s/step - loss: 0.5363 - accuracy: 0.7835 - precision: 0.8078 - val_loss: 2.3487 - val_accuracy: 0.3921 - val_precision: 0.3994
# Epoch 22/100
# 62/62 [==============================] - ETA: 0s - loss: 0.5200 - accuracy: 0.8008 - precision: 0.8269
# Epoch 22: accuracy did not improve from 0.80589
# 62/62 [==============================] - 326s 5s/step - loss: 0.5200 - accuracy: 0.8008 - precision: 0.8269 - val_loss: 2.5018 - val_accuracy: 0.3760 - val_precision: 0.3900
# Epoch 23/100
# 62/62 [==============================] - ETA: 0s - loss: 0.4354 - accuracy: 0.8247 - precision: 0.8476
# Epoch 23: accuracy improved from 0.80589 to 0.82470, saving model to model.h5
# 62/62 [==============================] - 329s 5s/step - loss: 0.4354 - accuracy: 0.8247 - precision: 0.8476 - val_loss: 0.8048 - val_accuracy: 0.7238 - val_precision: 0.7374
# Epoch 24/100
# 62/62 [==============================] - ETA: 0s - loss: 0.4635 - accuracy: 0.8232 - precision: 0.8453
# Epoch 24: accuracy did not improve from 0.82470
# 62/62 [==============================] - 331s 5s/step - loss: 0.4635 - accuracy: 0.8232 - precision: 0.8453 - val_loss: 0.7249 - val_accuracy: 0.7611 - val_precision: 0.7704
# Epoch 25/100
# 62/62 [==============================] - ETA: 0s - loss: 0.4265 - accuracy: 0.8288 - precision: 0.8508
# Epoch 25: accuracy improved from 0.82470 to 0.82876, saving model to model.h5
# 62/62 [==============================] - 328s 5s/step - loss: 0.4265 - accuracy: 0.8288 - precision: 0.8508 - val_loss: 5.2950 - val_accuracy: 0.4163 - val_precision: 0.4274
# Epoch 26/100
# 62/62 [==============================] - ETA: 0s - loss: 0.4405 - accuracy: 0.8277 - precision: 0.8448
# Epoch 26: accuracy did not improve from 0.82876
# 62/62 [==============================] - 328s 5s/step - loss: 0.4405 - accuracy: 0.8277 - precision: 0.8448 - val_loss: 7.1434 - val_accuracy: 0.3256 - val_precision: 0.3296
# Epoch 27/100
# 62/62 [==============================] - ETA: 0s - loss: 0.3537 - accuracy: 0.8608 - precision: 0.8768
# Epoch 27: accuracy improved from 0.82876 to 0.86077, saving model to model.h5
# 62/62 [==============================] - 327s 5s/step - loss: 0.3537 - accuracy: 0.8608 - precision: 0.8768 - val_loss: 2.9617 - val_accuracy: 0.4395 - val_precision: 0.4440
# Epoch 28/100
# 62/62 [==============================] - ETA: 0s - loss: 0.3572 - accuracy: 0.8592 - precision: 0.8772
# Epoch 28: accuracy did not improve from 0.86077
# 62/62 [==============================] - 321s 5s/step - loss: 0.3572 - accuracy: 0.8592 - precision: 0.8772 - val_loss: 1.5369 - val_accuracy: 0.6149 - val_precision: 0.6266
# Epoch 29/100
# 62/62 [==============================] - ETA: 0s - loss: 0.3543 - accuracy: 0.8664 - precision: 0.8797
# Epoch 29: accuracy improved from 0.86077 to 0.86636, saving model to model.h5
# 62/62 [==============================] - 328s 5s/step - loss: 0.3543 - accuracy: 0.8664 - precision: 0.8797 - val_loss: 1.5314 - val_accuracy: 0.6391 - val_precision: 0.6439
# Epoch 30/100
# 62/62 [==============================] - ETA: 0s - loss: 0.3654 - accuracy: 0.8567 - precision: 0.8725
# Epoch 30: accuracy did not improve from 0.86636
# 62/62 [==============================] - 322s 5s/step - loss: 0.3654 - accuracy: 0.8567 - precision: 0.8725 - val_loss: 0.5744 - val_accuracy: 0.7933 - val_precision: 0.8040
# Epoch 31/100
# 62/62 [==============================] - ETA: 0s - loss: 0.3079 - accuracy: 0.8780 - precision: 0.8931
# Epoch 31: accuracy improved from 0.86636 to 0.87805, saving model to model.h5
# 62/62 [==============================] - 333s 5s/step - loss: 0.3079 - accuracy: 0.8780 - precision: 0.8931 - val_loss: 1.2502 - val_accuracy: 0.6885 - val_precision: 0.7123
# Epoch 32/100
# 62/62 [==============================] - ETA: 0s - loss: 0.3211 - accuracy: 0.8750 - precision: 0.8839
# Epoch 32: accuracy did not improve from 0.87805
# 62/62 [==============================] - 326s 5s/step - loss: 0.3211 - accuracy: 0.8750 - precision: 0.8839 - val_loss: 0.9402 - val_accuracy: 0.7772 - val_precision: 0.7838
# Epoch 33/100
# 62/62 [==============================] - ETA: 0s - loss: 0.3717 - accuracy: 0.8598 - precision: 0.8723
# Epoch 33: accuracy did not improve from 0.87805
# 62/62 [==============================] - 328s 5s/step - loss: 0.3717 - accuracy: 0.8598 - precision: 0.8723 - val_loss: 1.7436 - val_accuracy: 0.5736 - val_precision: 0.5752
# Epoch 34/100
# 62/62 [==============================] - ETA: 0s - loss: 0.3079 - accuracy: 0.8826 - precision: 0.8922
# Epoch 34: accuracy improved from 0.87805 to 0.88262, saving model to model.h5
# 62/62 [==============================] - 328s 5s/step - loss: 0.3079 - accuracy: 0.8826 - precision: 0.8922 - val_loss: 0.6592 - val_accuracy: 0.7923 - val_precision: 0.8037
# Epoch 35/100
# 62/62 [==============================] - ETA: 0s - loss: 0.2901 - accuracy: 0.8862 - precision: 0.8981
# Epoch 35: accuracy improved from 0.88262 to 0.88618, saving model to model.h5
# 62/62 [==============================] - 320s 5s/step - loss: 0.2901 - accuracy: 0.8862 - precision: 0.8981 - val_loss: 2.2631 - val_accuracy: 0.4990 - val_precision: 0.5053
# Epoch 36/100
# 62/62 [==============================] - ETA: 0s - loss: 0.3424 - accuracy: 0.8709 - precision: 0.8857
# Epoch 36: accuracy did not improve from 0.88618
# 62/62 [==============================] - 319s 5s/step - loss: 0.3424 - accuracy: 0.8709 - precision: 0.8857 - val_loss: 0.9840 - val_accuracy: 0.7208 - val_precision: 0.7238
# Epoch 37/100
# 62/62 [==============================] - ETA: 0s - loss: 0.3380 - accuracy: 0.8770 - precision: 0.8858
# Epoch 37: accuracy did not improve from 0.88618
# 62/62 [==============================] - 305s 5s/step - loss: 0.3380 - accuracy: 0.8770 - precision: 0.8858 - val_loss: 4.6849 - val_accuracy: 0.3831 - val_precision: 0.3876
# Epoch 38/100
# 62/62 [==============================] - ETA: 0s - loss: 0.3085 - accuracy: 0.8826 - precision: 0.8916
# Epoch 38: accuracy did not improve from 0.88618
# 62/62 [==============================] - 310s 5s/step - loss: 0.3085 - accuracy: 0.8826 - precision: 0.8916 - val_loss: 5.1292 - val_accuracy: 0.3377 - val_precision: 0.3384
# Epoch 39/100
# 62/62 [==============================] - ETA: 0s - loss: 0.2941 - accuracy: 0.8913 - precision: 0.9003
# Epoch 39: accuracy improved from 0.88618 to 0.89126, saving model to model.h5
# 62/62 [==============================] - 330s 5s/step - loss: 0.2941 - accuracy: 0.8913 - precision: 0.9003 - val_loss: 17.0691 - val_accuracy: 0.2056 - val_precision: 0.2040
# Epoch 40/100
# 62/62 [==============================] - ETA: 0s - loss: 0.3097 - accuracy: 0.8811 - precision: 0.8946
# Epoch 40: accuracy did not improve from 0.89126
# 62/62 [==============================] - 326s 5s/step - loss: 0.3097 - accuracy: 0.8811 - precision: 0.8946 - val_loss: 2.7575 - val_accuracy: 0.4980 - val_precision: 0.5031
# Epoch 41/100
# 62/62 [==============================] - ETA: 0s - loss: 0.3043 - accuracy: 0.8816 - precision: 0.8953
# Epoch 41: accuracy did not improve from 0.89126
# 62/62 [==============================] - 329s 5s/step - loss: 0.3043 - accuracy: 0.8816 - precision: 0.8953 - val_loss: 0.9602 - val_accuracy: 0.7298 - val_precision: 0.7402
# Epoch 42/100
# 62/62 [==============================] - ETA: 0s - loss: 0.2425 - accuracy: 0.9096 - precision: 0.9170
# Epoch 42: accuracy improved from 0.89126 to 0.90955, saving model to model.h5
# 62/62 [==============================] - 329s 5s/step - loss: 0.2425 - accuracy: 0.9096 - precision: 0.9170 - val_loss: 0.4553 - val_accuracy: 0.8438 - val_precision: 0.8517
# Epoch 43/100
# 62/62 [==============================] - ETA: 0s - loss: 0.2077 - accuracy: 0.9217 - precision: 0.9305
# Epoch 43: accuracy improved from 0.90955 to 0.92175, saving model to model.h5
# 62/62 [==============================] - 305s 5s/step - loss: 0.2077 - accuracy: 0.9217 - precision: 0.9305 - val_loss: 3.3720 - val_accuracy: 0.5907 - val_precision: 0.5923
# Epoch 44/100
# 62/62 [==============================] - ETA: 0s - loss: 0.2235 - accuracy: 0.9141 - precision: 0.9240
# Epoch 44: accuracy did not improve from 0.92175
# 62/62 [==============================] - 303s 5s/step - loss: 0.2235 - accuracy: 0.9141 - precision: 0.9240 - val_loss: 5.5182 - val_accuracy: 0.3659 - val_precision: 0.3646
# Epoch 45/100
# 62/62 [==============================] - ETA: 0s - loss: 0.2205 - accuracy: 0.9207 - precision: 0.9298
# Epoch 45: accuracy did not improve from 0.92175
# 62/62 [==============================] - 303s 5s/step - loss: 0.2205 - accuracy: 0.9207 - precision: 0.9298 - val_loss: 1.2108 - val_accuracy: 0.7873 - val_precision: 0.7869
# Epoch 46/100
# 62/62 [==============================] - ETA: 0s - loss: 0.2448 - accuracy: 0.9136 - precision: 0.9179
# Epoch 46: accuracy did not improve from 0.92175
# 62/62 [==============================] - 304s 5s/step - loss: 0.2448 - accuracy: 0.9136 - precision: 0.9179 - val_loss: 2.5082 - val_accuracy: 0.6421 - val_precision: 0.6472
# Epoch 47/100
# 62/62 [==============================] - ETA: 0s - loss: 0.2154 - accuracy: 0.9177 - precision: 0.9221
# Epoch 47: accuracy did not improve from 0.92175
# 62/62 [==============================] - 303s 5s/step - loss: 0.2154 - accuracy: 0.9177 - precision: 0.9221 - val_loss: 1.3999 - val_accuracy: 0.7036 - val_precision: 0.7113
# Epoch 48/100
# 62/62 [==============================] - ETA: 0s - loss: 0.2538 - accuracy: 0.9050 - precision: 0.9105
# Epoch 48: accuracy did not improve from 0.92175
# 62/62 [==============================] - 303s 5s/step - loss: 0.2538 - accuracy: 0.9050 - precision: 0.9105 - val_loss: 5.7745 - val_accuracy: 0.3327 - val_precision: 0.3333
# Epoch 49/100
# 62/62 [==============================] - ETA: 0s - loss: 0.2198 - accuracy: 0.9238 - precision: 0.9299
# Epoch 49: accuracy improved from 0.92175 to 0.92378, saving model to model.h5
# 62/62 [==============================] - 305s 5s/step - loss: 0.2198 - accuracy: 0.9238 - precision: 0.9299 - val_loss: 8.9356 - val_accuracy: 0.2208 - val_precision: 0.2212
# Epoch 50/100
# 62/62 [==============================] - ETA: 0s - loss: 0.1821 - accuracy: 0.9345 - precision: 0.9390
# Epoch 50: accuracy improved from 0.92378 to 0.93445, saving model to model.h5
# 62/62 [==============================] - 307s 5s/step - loss: 0.1821 - accuracy: 0.9345 - precision: 0.9390 - val_loss: 4.7994 - val_accuracy: 0.3518 - val_precision: 0.3563
# Epoch 51/100
# 62/62 [==============================] - ETA: 0s - loss: 0.1747 - accuracy: 0.9405 - precision: 0.9436
# Epoch 51: accuracy improved from 0.93445 to 0.94055, saving model to model.h5
# 62/62 [==============================] - 308s 5s/step - loss: 0.1747 - accuracy: 0.9405 - precision: 0.9436 - val_loss: 6.3460 - val_accuracy: 0.3690 - val_precision: 0.3712
# Epoch 52/100
# 62/62 [==============================] - ETA: 0s - loss: 0.1713 - accuracy: 0.9375 - precision: 0.9416
# Epoch 52: accuracy did not improve from 0.94055
# 62/62 [==============================] - 329s 5s/step - loss: 0.1713 - accuracy: 0.9375 - precision: 0.9416 - val_loss: 3.5607 - val_accuracy: 0.5010 - val_precision: 0.5136
# Epoch 53/100
# 62/62 [==============================] - ETA: 0s - loss: 0.2312 - accuracy: 0.9157 - precision: 0.9219
# Epoch 53: accuracy did not improve from 0.94055
# 62/62 [==============================] - 329s 5s/step - loss: 0.2312 - accuracy: 0.9157 - precision: 0.9219 - val_loss: 4.6211 - val_accuracy: 0.5252 - val_precision: 0.5285
# Epoch 54/100
# 62/62 [==============================] - ETA: 0s - loss: 0.3033 - accuracy: 0.8958 - precision: 0.8994
# Epoch 54: accuracy did not improve from 0.94055
# 62/62 [==============================] - 323s 5s/step - loss: 0.3033 - accuracy: 0.8958 - precision: 0.8994 - val_loss: 3.9700 - val_accuracy: 0.4284 - val_precision: 0.4334
# Epoch 55/100
# 62/62 [==============================] - ETA: 0s - loss: 0.1624 - accuracy: 0.9365 - precision: 0.9421
# Epoch 55: accuracy did not improve from 0.94055
# 62/62 [==============================] - 329s 5s/step - loss: 0.1624 - accuracy: 0.9365 - precision: 0.9421 - val_loss: 5.5203 - val_accuracy: 0.3387 - val_precision: 0.3340
# Epoch 56/100
# 62/62 [==============================] - ETA: 0s - loss: 0.1520 - accuracy: 0.9492 - precision: 0.9508
# Epoch 56: accuracy improved from 0.94055 to 0.94919, saving model to model.h5
# 62/62 [==============================] - 325s 5s/step - loss: 0.1520 - accuracy: 0.9492 - precision: 0.9508 - val_loss: 2.8390 - val_accuracy: 0.6038 - val_precision: 0.6092
# Epoch 57/100
# 62/62 [==============================] - ETA: 0s - loss: 0.1364 - accuracy: 0.9482 - precision: 0.9514
# Epoch 57: accuracy did not improve from 0.94919
# 62/62 [==============================] - 324s 5s/step - loss: 0.1364 - accuracy: 0.9482 - precision: 0.9514 - val_loss: 0.6941 - val_accuracy: 0.7984 - val_precision: 0.8053
# Epoch 58/100
# 62/62 [==============================] - ETA: 0s - loss: 0.2198 - accuracy: 0.9233 - precision: 0.9295
# Epoch 58: accuracy did not improve from 0.94919
# 62/62 [==============================] - 328s 5s/step - loss: 0.2198 - accuracy: 0.9233 - precision: 0.9295 - val_loss: 0.9254 - val_accuracy: 0.7571 - val_precision: 0.7728
# Epoch 59/100
# 62/62 [==============================] - ETA: 0s - loss: 0.1538 - accuracy: 0.9400 - precision: 0.9442
# Epoch 59: accuracy did not improve from 0.94919
# 62/62 [==============================] - 323s 5s/step - loss: 0.1538 - accuracy: 0.9400 - precision: 0.9442 - val_loss: 2.5231 - val_accuracy: 0.5111 - val_precision: 0.5148
# Epoch 60/100
# 62/62 [==============================] - ETA: 0s - loss: 0.1408 - accuracy: 0.9502 - precision: 0.9534
# Epoch 60: accuracy improved from 0.94919 to 0.95020, saving model to model.h5
# 62/62 [==============================] - 317s 5s/step - loss: 0.1408 - accuracy: 0.9502 - precision: 0.9534 - val_loss: 6.7569 - val_accuracy: 0.4929 - val_precision: 0.4929
# Epoch 61/100
# 62/62 [==============================] - ETA: 0s - loss: 0.1332 - accuracy: 0.9563 - precision: 0.9586
# Epoch 61: accuracy improved from 0.95020 to 0.95630, saving model to model.h5
# 62/62 [==============================] - 318s 5s/step - loss: 0.1332 - accuracy: 0.9563 - precision: 0.9586 - val_loss: 1.6675 - val_accuracy: 0.6492 - val_precision: 0.6543
# Epoch 62/100
# 62/62 [==============================] - ETA: 0s - loss: 0.1604 - accuracy: 0.9400 - precision: 0.9427
# Epoch 62: accuracy did not improve from 0.95630
# 62/62 [==============================] - 318s 5s/step - loss: 0.1604 - accuracy: 0.9400 - precision: 0.9427 - val_loss: 3.8355 - val_accuracy: 0.5323 - val_precision: 0.5344
# Epoch 63/100
# 62/62 [==============================] - ETA: 0s - loss: 0.1457 - accuracy: 0.9466 - precision: 0.9508
# Epoch 63: accuracy did not improve from 0.95630
# 62/62 [==============================] - 323s 5s/step - loss: 0.1457 - accuracy: 0.9466 - precision: 0.9508 - val_loss: 0.6062 - val_accuracy: 0.8105 - val_precision: 0.8180
# Epoch 64/100
# 62/62 [==============================] - ETA: 0s - loss: 0.1569 - accuracy: 0.9507 - precision: 0.9525
# Epoch 64: accuracy did not improve from 0.95630
# 62/62 [==============================] - 314s 5s/step - loss: 0.1569 - accuracy: 0.9507 - precision: 0.9525 - val_loss: 0.2971 - val_accuracy: 0.9173 - val_precision: 0.9172
# Epoch 65/100
# 62/62 [==============================] - ETA: 0s - loss: 0.1316 - accuracy: 0.9517 - precision: 0.9539
# Epoch 65: accuracy did not improve from 0.95630
# 62/62 [==============================] - 321s 5s/step - loss: 0.1316 - accuracy: 0.9517 - precision: 0.9539 - val_loss: 3.2359 - val_accuracy: 0.5252 - val_precision: 0.5266
# Epoch 66/100
# 62/62 [==============================] - ETA: 0s - loss: 0.1679 - accuracy: 0.9400 - precision: 0.9428
# Epoch 66: accuracy did not improve from 0.95630
# 62/62 [==============================] - 304s 5s/step - loss: 0.1679 - accuracy: 0.9400 - precision: 0.9428 - val_loss: 1.2648 - val_accuracy: 0.7651 - val_precision: 0.7797
# Epoch 67/100
# 62/62 [==============================] - ETA: 0s - loss: 0.2521 - accuracy: 0.9136 - precision: 0.9175
# Epoch 67: accuracy did not improve from 0.95630
# 62/62 [==============================] - 316s 5s/step - loss: 0.2521 - accuracy: 0.9136 - precision: 0.9175 - val_loss: 2.8873 - val_accuracy: 0.5302 - val_precision: 0.5340
# Epoch 68/100
# 62/62 [==============================] - ETA: 0s - loss: 0.3484 - accuracy: 0.9004 - precision: 0.9036
# Epoch 68: accuracy did not improve from 0.95630
# 62/62 [==============================] - 330s 5s/step - loss: 0.3484 - accuracy: 0.9004 - precision: 0.9036 - val_loss: 2.1704 - val_accuracy: 0.6905 - val_precision: 0.6935
# Epoch 69/100
# 62/62 [==============================] - ETA: 0s - loss: 0.1815 - accuracy: 0.9299 - precision: 0.9349
# Epoch 69: accuracy did not improve from 0.95630
# 62/62 [==============================] - 329s 5s/step - loss: 0.1815 - accuracy: 0.9299 - precision: 0.9349 - val_loss: 0.4297 - val_accuracy: 0.8609 - val_precision: 0.8679
# Epoch 70/100
# 62/62 [==============================] - ETA: 0s - loss: 0.1678 - accuracy: 0.9426 - precision: 0.9453
# Epoch 70: accuracy did not improve from 0.95630
# 62/62 [==============================] - 327s 5s/step - loss: 0.1678 - accuracy: 0.9426 - precision: 0.9453 - val_loss: 1.2713 - val_accuracy: 0.6815 - val_precision: 0.6925
# Epoch 71/100
# 62/62 [==============================] - ETA: 0s - loss: 0.1683 - accuracy: 0.9411 - precision: 0.9433
# Epoch 71: accuracy did not improve from 0.95630
# 62/62 [==============================] - 325s 5s/step - loss: 0.1683 - accuracy: 0.9411 - precision: 0.9433 - val_loss: 0.3806 - val_accuracy: 0.8831 - val_precision: 0.8893
# Epoch 72/100
# 62/62 [==============================] - ETA: 0s - loss: 0.1447 - accuracy: 0.9487 - precision: 0.9518
# Epoch 72: accuracy did not improve from 0.95630
# 62/62 [==============================] - 329s 5s/step - loss: 0.1447 - accuracy: 0.9487 - precision: 0.9518 - val_loss: 2.9080 - val_accuracy: 0.5565 - val_precision: 0.5654
# Epoch 73/100
# 62/62 [==============================] - ETA: 0s - loss: 0.1571 - accuracy: 0.9466 - precision: 0.9509
# Epoch 73: accuracy did not improve from 0.95630
# 62/62 [==============================] - 326s 5s/step - loss: 0.1571 - accuracy: 0.9466 - precision: 0.9509 - val_loss: 0.8465 - val_accuracy: 0.8014 - val_precision: 0.8071
# Epoch 74/100
# 62/62 [==============================] - ETA: 0s - loss: 0.1382 - accuracy: 0.9548 - precision: 0.9552
# Epoch 74: accuracy did not improve from 0.95630
# 62/62 [==============================] - 324s 5s/step - loss: 0.1382 - accuracy: 0.9548 - precision: 0.9552 - val_loss: 0.4714 - val_accuracy: 0.8619 - val_precision: 0.8704
# Epoch 75/100
# 62/62 [==============================] - ETA: 0s - loss: 0.1059 - accuracy: 0.9639 - precision: 0.9663
# Epoch 75: accuracy improved from 0.95630 to 0.96392, saving model to model.h5
# 62/62 [==============================] - 322s 5s/step - loss: 0.1059 - accuracy: 0.9639 - precision: 0.9663 - val_loss: 0.3781 - val_accuracy: 0.8821 - val_precision: 0.8922
# Epoch 76/100
# 62/62 [==============================] - ETA: 0s - loss: 0.1184 - accuracy: 0.9599 - precision: 0.9618
# Epoch 76: accuracy did not improve from 0.96392
# 62/62 [==============================] - 312s 5s/step - loss: 0.1184 - accuracy: 0.9599 - precision: 0.9618 - val_loss: 1.7442 - val_accuracy: 0.7006 - val_precision: 0.7022
# Epoch 77/100
# 62/62 [==============================] - ETA: 0s - loss: 0.1551 - accuracy: 0.9456 - precision: 0.9499
# Epoch 77: accuracy did not improve from 0.96392
# 62/62 [==============================] - 333s 5s/step - loss: 0.1551 - accuracy: 0.9456 - precision: 0.9499 - val_loss: 1.0821 - val_accuracy: 0.7601 - val_precision: 0.7642
# Epoch 78/100
# 62/62 [==============================] - ETA: 0s - loss: 0.0854 - accuracy: 0.9675 - precision: 0.9684
# Epoch 78: accuracy improved from 0.96392 to 0.96748, saving model to model.h5
# 62/62 [==============================] - 328s 5s/step - loss: 0.0854 - accuracy: 0.9675 - precision: 0.9684 - val_loss: 0.4162 - val_accuracy: 0.8790 - val_precision: 0.8896
# Epoch 79/100
# 62/62 [==============================] - ETA: 0s - loss: 0.0722 - accuracy: 0.9741 - precision: 0.9746
# Epoch 79: accuracy improved from 0.96748 to 0.97409, saving model to model.h5
# 62/62 [==============================] - 328s 5s/step - loss: 0.0722 - accuracy: 0.9741 - precision: 0.9746 - val_loss: 0.4526 - val_accuracy: 0.8710 - val_precision: 0.8745
# Epoch 80/100
# 62/62 [==============================] - ETA: 0s - loss: 0.0749 - accuracy: 0.9761 - precision: 0.9776
# Epoch 80: accuracy improved from 0.97409 to 0.97612, saving model to model.h5
# 62/62 [==============================] - 327s 5s/step - loss: 0.0749 - accuracy: 0.9761 - precision: 0.9776 - val_loss: 1.3292 - val_accuracy: 0.7470 - val_precision: 0.7561
# Epoch 81/100
# 62/62 [==============================] - ETA: 0s - loss: 0.0889 - accuracy: 0.9685 - precision: 0.9704
# Epoch 81: accuracy did not improve from 0.97612
# 62/62 [==============================] - 318s 5s/step - loss: 0.0889 - accuracy: 0.9685 - precision: 0.9704 - val_loss: 1.3976 - val_accuracy: 0.7510 - val_precision: 0.7566
# Epoch 82/100
# 62/62 [==============================] - ETA: 0s - loss: 0.1406 - accuracy: 0.9563 - precision: 0.9567
# Epoch 82: accuracy did not improve from 0.97612
# 62/62 [==============================] - 321s 5s/step - loss: 0.1406 - accuracy: 0.9563 - precision: 0.9567 - val_loss: 11.1871 - val_accuracy: 0.3841 - val_precision: 0.3828
# Epoch 83/100
# 62/62 [==============================] - ETA: 0s - loss: 0.1258 - accuracy: 0.9634 - precision: 0.9658
# Epoch 83: accuracy did not improve from 0.97612
# 62/62 [==============================] - 328s 5s/step - loss: 0.1258 - accuracy: 0.9634 - precision: 0.9658 - val_loss: 3.7323 - val_accuracy: 0.5585 - val_precision: 0.5569
# Epoch 84/100
# 62/62 [==============================] - ETA: 0s - loss: 0.0657 - accuracy: 0.9751 - precision: 0.9755
# Epoch 84: accuracy did not improve from 0.97612
# 62/62 [==============================] - 308s 5s/step - loss: 0.0657 - accuracy: 0.9751 - precision: 0.9755 - val_loss: 0.7018 - val_accuracy: 0.8407 - val_precision: 0.8421
# Epoch 85/100
# 62/62 [==============================] - ETA: 0s - loss: 0.1169 - accuracy: 0.9609 - precision: 0.9633
# Epoch 85: accuracy did not improve from 0.97612
# 62/62 [==============================] - 304s 5s/step - loss: 0.1169 - accuracy: 0.9609 - precision: 0.9633 - val_loss: 0.9811 - val_accuracy: 0.7722 - val_precision: 0.7780
# Epoch 86/100
# 62/62 [==============================] - ETA: 0s - loss: 0.1172 - accuracy: 0.9583 - precision: 0.9627
# Epoch 86: accuracy did not improve from 0.97612
# 62/62 [==============================] - 327s 5s/step - loss: 0.1172 - accuracy: 0.9583 - precision: 0.9627 - val_loss: 0.6632 - val_accuracy: 0.8367 - val_precision: 0.8398
# Epoch 87/100
# 62/62 [==============================] - ETA: 0s - loss: 0.0946 - accuracy: 0.9685 - precision: 0.9699
# Epoch 87: accuracy did not improve from 0.97612
# 62/62 [==============================] - 307s 5s/step - loss: 0.0946 - accuracy: 0.9685 - precision: 0.9699 - val_loss: 1.9395 - val_accuracy: 0.6250 - val_precision: 0.6273
# Epoch 88/100
# 62/62 [==============================] - ETA: 0s - loss: 0.1340 - accuracy: 0.9543 - precision: 0.9552
# Epoch 88: accuracy did not improve from 0.97612
# 62/62 [==============================] - 307s 5s/step - loss: 0.1340 - accuracy: 0.9543 - precision: 0.9552 - val_loss: 5.9380 - val_accuracy: 0.4052 - val_precision: 0.4052
# Epoch 89/100
# 62/62 [==============================] - ETA: 0s - loss: 0.1525 - accuracy: 0.9507 - precision: 0.9536
# Epoch 89: accuracy did not improve from 0.97612
# 62/62 [==============================] - 307s 5s/step - loss: 0.1525 - accuracy: 0.9507 - precision: 0.9536 - val_loss: 0.9098 - val_accuracy: 0.7883 - val_precision: 0.7935
# Epoch 90/100
# 62/62 [==============================] - ETA: 0s - loss: 0.1986 - accuracy: 0.9375 - precision: 0.9393
# Epoch 90: accuracy did not improve from 0.97612
# 62/62 [==============================] - 306s 5s/step - loss: 0.1986 - accuracy: 0.9375 - precision: 0.9393 - val_loss: 5.5449 - val_accuracy: 0.4415 - val_precision: 0.4438
# Epoch 91/100
# 62/62 [==============================] - ETA: 0s - loss: 0.1275 - accuracy: 0.9573 - precision: 0.9588
# Epoch 91: accuracy did not improve from 0.97612
# 62/62 [==============================] - 306s 5s/step - loss: 0.1275 - accuracy: 0.9573 - precision: 0.9588 - val_loss: 1.6970 - val_accuracy: 0.6643 - val_precision: 0.6677
# Epoch 92/100
# 62/62 [==============================] - ETA: 0s - loss: 0.0807 - accuracy: 0.9736 - precision: 0.9745
# Epoch 92: accuracy did not improve from 0.97612
# 62/62 [==============================] - 308s 5s/step - loss: 0.0807 - accuracy: 0.9736 - precision: 0.9745 - val_loss: 1.0112 - val_accuracy: 0.7782 - val_precision: 0.7864
# Epoch 93/100
# 62/62 [==============================] - ETA: 0s - loss: 0.0758 - accuracy: 0.9741 - precision: 0.9751
# Epoch 93: accuracy did not improve from 0.97612
# 62/62 [==============================] - 308s 5s/step - loss: 0.0758 - accuracy: 0.9741 - precision: 0.9751 - val_loss: 0.7841 - val_accuracy: 0.7913 - val_precision: 0.7953
# Epoch 94/100
# 62/62 [==============================] - ETA: 0s - loss: 0.1102 - accuracy: 0.9624 - precision: 0.9638
# Epoch 94: accuracy did not improve from 0.97612
# 62/62 [==============================] - 317s 5s/step - loss: 0.1102 - accuracy: 0.9624 - precision: 0.9638 - val_loss: 0.4668 - val_accuracy: 0.8952 - val_precision: 0.8998
# Epoch 95/100
# 62/62 [==============================] - ETA: 0s - loss: 0.0845 - accuracy: 0.9721 - precision: 0.9725
# Epoch 95: accuracy did not improve from 0.97612
# 62/62 [==============================] - 313s 5s/step - loss: 0.0845 - accuracy: 0.9721 - precision: 0.9725 - val_loss: 0.7617 - val_accuracy: 0.8216 - val_precision: 0.8249
# Epoch 96/100
# 62/62 [==============================] - ETA: 0s - loss: 0.1379 - accuracy: 0.9593 - precision: 0.9613
# Epoch 96: accuracy did not improve from 0.97612
# 62/62 [==============================] - 344s 6s/step - loss: 0.1379 - accuracy: 0.9593 - precision: 0.9613 - val_loss: 0.4014 - val_accuracy: 0.8962 - val_precision: 0.8962
# Epoch 97/100
# 62/62 [==============================] - ETA: 0s - loss: 0.1143 - accuracy: 0.9593 - precision: 0.9603
# Epoch 97: accuracy did not improve from 0.97612
# 62/62 [==============================] - 345s 6s/step - loss: 0.1143 - accuracy: 0.9593 - precision: 0.9603 - val_loss: 1.4542 - val_accuracy: 0.7369 - val_precision: 0.7418
# Epoch 98/100
# 62/62 [==============================] - ETA: 0s - loss: 0.0594 - accuracy: 0.9807 - precision: 0.9812
# Epoch 98: accuracy improved from 0.97612 to 0.98069, saving model to model.h5
# 62/62 [==============================] - 306s 5s/step - loss: 0.0594 - accuracy: 0.9807 - precision: 0.9812 - val_loss: 0.0528 - val_accuracy: 0.9798 - val_precision: 0.9817
# Epoch 99/100
# 62/62 [==============================] - ETA: 0s - loss: 0.0750 - accuracy: 0.9731 - precision: 0.9750
# Epoch 99: accuracy did not improve from 0.98069
# 62/62 [==============================] - 304s 5s/step - loss: 0.0750 - accuracy: 0.9731 - precision: 0.9750 - val_loss: 0.4264 - val_accuracy: 0.8810 - val_precision: 0.8900
# Epoch 100/100
# 62/62 [==============================] - ETA: 0s - loss: 0.0907 - accuracy: 0.9660 - precision: 0.9703
# Epoch 100: accuracy did not improve from 0.98069
# 62/62 [==============================] - 304s 5s/step - loss: 0.0907 - accuracy: 0.9660 - precision: 0.9703 - val_loss: 0.6105 - val_accuracy: 0.8478 - val_precision: 0.8529
# 15/15 [==============================] - 85s 6s/step - loss: 0.3356 - accuracy: 0.8313 - precision: 0.8330 - val_loss: 2.1716 - val_accuracy: 0.5521 - val_precision: 0.5493
# Epoch 97/100
# 15/15 [==============================] - ETA: 0s - loss: 0.3385 - accuracy: 0.8438 - precision: 0.8434
# Epoch 97: accuracy did not improve from 0.87931
# 15/15 [==============================] - 88s 6s/step - loss: 0.3385 - accuracy: 0.8438 - precision: 0.8434 - val_loss: 0.3798 - val_accuracy: 0.8417 - val_precision: 0.8428
# Epoch 98/100
# 15/15 [==============================] - ETA: 0s - loss: 0.2754 - accuracy: 0.8771 - precision: 0.8771
# Epoch 98: accuracy did not improve from 0.87931
# 15/15 [==============================] - 80s 5s/step - loss: 0.2754 - accuracy: 0.8771 - precision: 0.8771 - val_loss: 1.6037 - val_accuracy: 0.7042 - val_precision: 0.7056
# Epoch 99/100
# 15/15 [==============================] - ETA: 0s - loss: 0.2683 - accuracy: 0.8792 - precision: 0.8792
# Epoch 99: accuracy did not improve from 0.87931
# 15/15 [==============================] - 79s 5s/step - loss: 0.2683 - accuracy: 0.8792 - precision: 0.8792 - val_loss: 0.3100 - val_accuracy: 0.8604 - val_precision: 0.8619
# Epoch 100/100
# 15/15 [==============================] - ETA: 0s - loss: 0.2492 - accuracy: 0.8854 - precision: 0.8854
# Epoch 100: accuracy improved from 0.87931 to 0.88542, saving model to SHUFFLE.h5
# 15/15 [==============================] - 96s 7s/step - loss: 0.2492 - accuracy: 0.8854 - precision: 0.8854 - val_loss: 0.3089 - val_accuracy: 0.8479 - val_precision: 0.8494

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'precision', 'val_loss', 'val_accuracy', 'val_precision'])

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(20, 8))
plt.plot(history.history['accuracy'])

for i in range(epochs):
    if i%5 == 0:
        plt.annotate(np.round(history.history['accuracy'][i]*100,2),xy=(i,history.history['accuracy'][i]))

plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.show()

# %%
plt.figure(figsize=(20, 8))
plt.plot(history.history['loss'])

for i in range(epochs):
    if i%5 == 0:
        plt.annotate(np.round(history.history['loss'][i]*100,2),xy=(i,history.history['loss'][i]))

plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.show()
